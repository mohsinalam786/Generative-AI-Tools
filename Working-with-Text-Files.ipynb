# %%
# !pip install spacy

# %%
import spacy

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 61.8 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp("Hello, spaCy is siccessfully installed!")
print([token.text for token in doc])
# Out:
# ['Hello', ',', 'spaCy', 'is', 'siccessfully', 'installed', '!']

# %%
name = "Fred"
#USING THE OLD .format() METHOD:
print("His name is {var}.".format(var=name))

#USING F-strings:
print(f"His name is {name}.")
# Out:
# His name is Fred.
# His name is Fred.

# %%
# HIGHLIGHT
print(f"His name is {name!r}.")
# Out:
# His name is 'Fred'.

# %%
d = {"a":123, "b":456}
print(f"My address: {d["a"]} Main Street")
# Out:
# My address: 123 Main Street

# %%
library = [("Author", "Topic", "Pages"), ("Twain", "Rafting", 601), ("Feynman", "Physics", 95), ("Hamilton", "Mythology", 144)]
for i in library:
  print(f"{i[0]:{10}} {i[1]:{10}} {i[2]:{4}}")
# Out:
# Author     Topic      Pages
# Twain      Rafting     601
# Feynman    Physics      95
# Hamilton   Mythology   144

# %%
library = [("Author", "Topic", "Pages"), ("Twain", "Rafting", 601), ("Feynman", "Physics", 95), ("Hamilton", "Mythology", 144)]
for i in library:
  print(f"{i[0]:{10}} {i[1]:{8}} {i[2]:#>{7}}")
# Out:
# Author     Topic    ##Pages
# Twain      Rafting  ####601
# Feynman    Physics  #####95
# Hamilton   Mythology ####144

# %%
library = [("Author", "Topic", "Pages"), ("Twain", "Rafting", 601), ("Feynman", "Physics", 95), ("Hamilton", "Mythology", 144)]
for i in library:
  print(f"{i[0]:{10}} {i[1]:{8}} {i[2]:.>{7}}")
# Out:
# Author     Topic    ..Pages
# Twain      Rafting  ....601
# Feynman    Physics  .....95
# Hamilton   Mythology ....144

# %%
# DATETIME
from datetime import datetime
today = datetime(year = 2018, month = 1, day = 27)
print(f"{today: %b %D, %Y}")

from datetime import datetime
today = datetime(year = 2018, month = 1, day = 27)
print(f"{today: %B %D, %Y}")
# Out:
#  Jan 01/27/18, 2018
#  January 01/27/18, 2018

# %%
#CREATING A FILE WITH PYTHON
# %%writefile test.txt
Hello, this is quick text file.
This is second line of the file
# Out:
# Overwriting test.txt

# %%
# Open the text.txt file we created earlier
my_file =open("test.txt")
my_file.read()
# Out:
# 'Hello, this is quick text file.\nThis is second line of the file\n'

# %%
my_file.read()
# Out:
# ''

# %%
#SEEK TO THE START OF FILE(INDEX 0)
my_file.seek(0)
# Out:
# 0

# %%
# READ AGAIN
my_file.read()
# Out:
# 'Hello, this is quick text file.\nThis is second line of the file\n'

# %%
# CLOSE A FILE
my_file.close()

# %%
my_file = open("test.txt")

# %%
my_file.seek(0)
# Out:
# 0

# %%
my_file.readlines()
# Out:
# ['Hello, this is quick text file.\n', 'This is second line of the file\n']

# %%
my_file.close()

# %%
# HOW TO WRITE A FILE, PASSING "w+" LETS US READ AND WRITE TO THE FILE
my_file = open("test.txt", "w+")

# %%
my_file.write("This is the first line")
# Out:
# 22

# %%
my_file.seek(0)
# Out:
# 0

# %%
my_file.read()
# Out:
# 'This is the first line'

# %%
# APPEND
my_file = open("test.txt", "a+")
my_file.write("\nThis line is being appended to test.txt")
my_file.write("\nAnd another line is here.")
# Out:
# 26

# %%
my_file.seek(0)
print(my_file.read())
# Out:
# This is the first line
# This line is being appended to test.txt
# And another line is here.

# %%
# ALIASES AND CONTEXT MANAGERS
with open("test.txt", "r") as txt:
  second_line = txt.readlines()[1]
print(second_line)
# Out:
# This line is being appended to test.txt

# %%
with open("test.txt", "r") as txt:
  for line in txt:
    print(line, end = " ")
# Out:
# This is the first line
#  This line is being appended to test.txt
#  And another line is here.
